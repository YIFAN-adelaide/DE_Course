# %% [markdown]
# # CaseStudy - Apollo GTM Analytics
#
# CaseStudy from Apollo GTM Team.
# Datasets:
#     Copy of Apollo - GTM Analytics Case Study - Data.xlsx
#
# **Instructions:**
#
# Please carefully read instructions for each step to understand tasks.
#
# **Prerequisites:**
#
# 1. Python 3.10+
#
# 2. Jupyter Notebook / JupyterLab (or VS Code notebooks)

# %% [markdown]
# ## Table of Contents
# - [1 - Packages](#1)
# - [2 - Overview of the Problem set](#2)
#     - [Exercise 1](#ex-1)
#     - [Exercise 2](#ex-2)
#     - [Exercise 4](#ex-4)
#     - [Exercise 5](#ex-5)
#     - [Exercise 6](#ex-6)
#     - [Exercise 7](#ex-7)
#     - [Exercise 8 (Optional)](#ex-8)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages ##
#
# First, let's run the cell below to import all the packages that you will need during this assignment.
# - [numpy](https://numpy.org/doc/1.20/) is the fundamental package for scientific computing with Python.
# - [pandas](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <a name='2'></a>
# ## 2 - Overview of the Problem set ##
#
# **Problem Statement**: This dataset has two sheets:
# 1. agent_shifts: This sheet records the working shifts of support agents. Each row is one agent’s shift, including agent_id, the agent’s time zone, shift start/end time, and total hours. We use it to measure how many agents are available at different times and to evaluate whether staffing coverage matches demand.
#
# 2. support_requests: This sheet records customer support tickets. Each row is one ticket, including ticket_id, customer region, request time in UTC, resolution time, first assigned agent_id (may be missing), and customer satisfaction score. We use it to analyze ticket demand patterns over time/region, service outcomes (resolution time and satisfaction), and agent performance when a ticket is assigned.
#
# You will extract and understand this dataset.
# Let's get more familiar with the dataset.

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1
# Load two data sheets seperately and check data info.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2
# Basic quality checks:
#
# __agent_shifts__:
# 1. visualize how many agents work in each shift blocks.

# %%
# Your Codes Start Here

# %% [markdown]
# __support_requests__:
# 1. change the datatype of __first_agent_id__ to int.
# 2. drop rows whose __first_agent_id__ is missing or not between [1-50]
# 3. Unique __ticket_region__.
# 4. change __request_time_utc__ to agent working shift blocks.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-3'></a>
# ### Exercise 3
# You will do:
# Count how many requests in each Region and agent working shift blocks. Visualize this outcome.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4
# You will do:
# calculate the ticket volumes every four hours from each region.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-5'></a>
# ### Exercise 5
# You will do:
# Try to see the co-relationship between __customer_satisfaction__ and __resolution_time__

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6
# You will do:
# calculate the average resolution time for each agent.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-7'></a>
# ### Exercise 7
# You will do:
# Try to summarize the satisfaction score for each agent.

# %%
# Your Codes Start Here

# %% [markdown]
# <a name='ex-8'></a>
# ### Exercise 8 (Optional)
# You will do:
# Give different weights to both performance of an agent the efficiency and satisfaction, then modify weights to evaluate the performance and ability of an agent.

# %%
# Your Codes Start Here
